# %% [markdown]
# Load the requisite libraries.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Load the data frames:

# %%
schools = pd.read_csv("/Users/wratko/Documents/projects/tx-school_funding/jupyter-notebooks/bexar-county-schools - trad_ISD_CSD.csv")
data = pd.read_csv("/Users/wratko/Documents/projects/tx-school_funding/jupyter-notebooks/econ-disadv_data.csv")

# %%
display(schools,data)
# Out:
#             City           District       Charter Status  District #  \
# 0    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 1    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 2    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 3    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 4    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# ..           ...                ...                  ...         ...
# 450  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 451  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 452  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 453  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 454  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
#
#                    Campus  Campus #    Grade Group
# 0       ALAMO HEIGHTS H S  15901001    High School
# ...

# %%
ed_data = pd.merge(schools,data,on="Campus")

# %%
display(ed_data)
# Out:
#             City           District       Charter Status  District #  \
# 0    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 1    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 2    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 3    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# 4    San Antonio  Alamo Heights ISD  Traditional ISD/CSD       15901
# ..           ...                ...                  ...         ...
# 579  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 580  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 581  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 582  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
# 583  San Antonio      Southwest ISD  Traditional ISD/CSD       15912
#
#                    Campus  Campus #    Grade Group Pct Total 2019-20  \
# ...

# %%
ed_data.to_csv("/Users/wratko/Documents/projects/tx-school_funding/data/Econ-Disadntage_TX-2018-19_ELSI.csv")
